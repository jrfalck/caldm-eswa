# %%
import pandas as pd
df = pd.read_csv("results/appendix_a/adbench_per_run.csv")
datasets = sorted(df["dataset"].unique())
print(f"Total: {len(datasets)}")
for d in datasets:
    print(f"{d}.npz")
# Out:
# Total: 27
# 10_cover.npz
# 11_donors.npz
# 14_glass.npz
# 17_InternetAds.npz
# 18_Ionosphere.npz
# 19_landsat.npz
# 20_letter.npz
# 23_mammography.npz
# 24_mnist.npz
# 25_musk.npz
# 26_optdigits.npz
# 27_PageBlocks.npz
# 28_pendigits.npz
# 30_satellite.npz
# 31_satimage-2.npz
# 32_shuttle.npz
# 35_SpamBase.npz
# 36_speech.npz
# 38_thyroid.npz
# 3_backdoor.npz
# 40_vowels.npz
# 41_Waveform.npz
# 5_campaign.npz
# 6_cardio.npz
# 7_Cardiotocography.npz
# 8_celeba.npz
# 9_census.npz
